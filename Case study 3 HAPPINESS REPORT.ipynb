# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('happiness report.txt', delimiter='\t')

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Scatter plot
sns.scatterplot(data=df, x='GDP per capita', y='Score')
plt.title('GDP per capita vs. Happiness Score')
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = df.corr()

# Heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlations between Variables')
plt.show()
# Out:
# C:\Users\samik\AppData\Local\Temp\ipykernel_44312\4052400387.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
# Sort the dataframe by Happiness Score
sorted_df = df.sort_values('Score', ascending=False)

# %%
print(top_10_countries.columns)
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
# Bar plot
sns.barplot(data=top_10_countries, x='Score', y='Country or region')
plt.title('Score for Top 10 Countries')
plt.xlabel('Score')
plt.ylabel('Country')
plt.show()

# %%
# Box plot
sns.boxplot(data=df)
plt.title('Distribution of Variables')
plt.xticks(rotation=90)
plt.show()

# %%
# Pair plot
sns.pairplot(data=df)
plt.title('Relationship between Variables')
plt.show()
